# %% [markdown]
# <a href="https://colab.research.google.com/github/sahithisreya/DLT/blob/main/Bi_tempered_logistic_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/surmenok/keras_lr_finder.git keras_lr_finder_repo
# !mv keras_lr_finder_repo/keras_lr_finder keras_lr_finder
# !git clone https://github.com/google/bi-tempered-loss.git
# !mv bi-tempered-loss/tensorflow/loss.py loss.py
# !rm -r keras_lr_finder_repo bi-tempered-loss
# Out:
# Cloning into 'keras_lr_finder_repo'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 68 (delta 1), reused 2 (delta 0), pack-reused 62
# Receiving objects: 100% (68/68), 55.78 KiB | 4.29 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Cloning into 'bi-tempered-loss'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 152 (delta 15), reused 11 (delta 5), pack-reused 122
# Receiving objects: 100% (152/152), 65.60 KiB | 3.86 MiB/s, done.
# Resolving deltas: 100% (85/85), done.

# %%
# !git clone https://github.com/DumalaAnveshini/bitempered.git
from bitempered.utils import generate_points, mix_cifar, mix_points, points_to_data, get_best_lr
# Out:
# Cloning into 'bitempered'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (8/8), 740.39 KiB | 12.55 MiB/s, done.

# %%
from bitempered.plotting import plot_cifar, plot_points, plot_synthetic_results, plot_cifar_results, plot_lr_finding_results

# %%
from loss import _internal_bi_tempered_logistic_loss as bi_tempered_logistic_loss
from keras_lr_finder.lr_finder import LRFinder

# %%
import ssl

import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import resnet50
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Dense, Flatten, InputLayer, UpSampling2D
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical

# %%
cce = CategoricalCrossentropy(from_logits=False)
# %timeit cce(np.random.rand(1000, 10).astype(np.float32), np.random.rand(1000, 10).astype(np.float32))
# Out:
# 1.96 ms ± 77.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit bi_tempered_logistic_loss(np.random.rand(1000, 10).astype(np.float32), np.random.rand(1000, 10).astype(np.float32), 0.5, 2.)
# Out:
# 10 ms ± 1.26 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
class BiTemperedWrapper:

    def __init__(self, t1=1., t2=1.):
        self.t1 = t1
        self.t2 = t2
        self.cce = CategoricalCrossentropy(from_logits=True)

    def __call__(self, labels, activations):
        if self.t1 == 1. and self.t2 == 1.:
            return self.cce(labels, activations)
        return bi_tempered_logistic_loss(activations, labels, self.t1,  self.t2)

# %%
blue_train = generate_points(1200, 0, 5)
red_train = generate_points(1200, 6, 8)
blue_train_margin_noise, red_train_margin_noise = np.copy(blue_train), np.copy(red_train)
blue_train_global_noise, red_train_global_noise = np.copy(blue_train), np.copy(red_train)

mix_points(blue_train_margin_noise, red_train_margin_noise, 4, 7, 0.2)
mix_points(blue_train_global_noise, red_train_global_noise, 0, 8, 0.2)

plt.figure(figsize=(17, 5))
plt.subplot(1, 3, 1)
plt.title("Training data\nwithout noise")
plot_points([blue_train, red_train], 8)

plt.subplot(1, 3, 2)
plt.title("Training data\n20% margin noise")
plot_points([blue_train_margin_noise, red_train_margin_noise], 8)

plt.subplot(1, 3, 3)
plt.title("Training data\n20% global noise")
plot_points([blue_train_global_noise, red_train_global_noise], 8)
plt.show()

plt.figure(figsize=(6, 5))
blue_valid = generate_points(300, 0, 5)
red_valid = generate_points(300, 6, 8)
plt.title("Validation data")
plot_points([blue_valid, red_valid], 8)
plt.show()

# %%
X_train, y_train = points_to_data(blue_train, red_train)
X_train_margin, y_train_margin = points_to_data(blue_train_margin_noise, red_train_margin_noise)
X_train_global, y_train_global = points_to_data(blue_train_global_noise, red_train_global_noise)

X_valid, y_valid = points_to_data(blue_valid, red_valid)

# %%
def synthetic_model():
    return Sequential([
        InputLayer(input_shape=X_train[0].shape),
        Dense(32, activation='relu'),
        Dense(32, activation='relu'),
        Dense(2)
    ])

# %%
datasets = {'noise free': (X_train, y_train),
            'margin': (X_train_margin, y_train_margin),
            'global': (X_train_global, y_train_global)}
temp_vals = [(1., 1.), (0.2, 4.0)]
results = {}
for dataset_name, (X_data, y_data) in datasets.items():
    results[dataset_name] = {}
    for temps in temp_vals:
        results[dataset_name][temps] = {}
        model = synthetic_model()
        model.compile(loss=BiTemperedWrapper(*temps), optimizer=Adam(), metrics=['accuracy'])
        history = model.fit(X_data, y_data, validation_data=(X_valid, y_valid), epochs=20)
        results[dataset_name][temps]['model'] = model
        results[dataset_name][temps]['history'] = history.history
# Out:
# Epoch 1/20
# 75/75 [==============================] - 2s 7ms/step - loss: 0.5681 - accuracy: 0.6200 - val_loss: 0.4724 - val_accuracy: 0.7617
# Epoch 2/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.4002 - accuracy: 0.8350 - val_loss: 0.2990 - val_accuracy: 0.9300
# Epoch 3/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.2369 - accuracy: 0.9354 - val_loss: 0.1639 - val_accuracy: 0.9683
# Epoch 4/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1366 - accuracy: 0.9754 - val_loss: 0.1017 - val_accuracy: 0.9883
# Epoch 5/20
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0888 - accuracy: 0.9900 - val_loss: 0.0691 - val_accuracy: 0.9917
# Epoch 6/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0619 - accuracy: 0.9950 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 7/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0479 - accuracy: 0.9975 - val_loss: 0.0402 - val_accuracy: 1.0000
# Epoch 8/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0356 - accuracy: 0.9996 - val_loss: 0.0305 - val_accuracy: 0.9983
# Epoch 9/20
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 10/20
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0230 - accuracy: 0.9996 - val_loss: 0.0206 - val_accuracy: 1.0000
# Epoch 11/20
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 12/20
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 13/20
# 75/75 [==============================] - 1s 7ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 14/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 15/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 16/20
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 17/20
# 75/75 [==============================] - 1s 12ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 18/20
# 75/75 [==============================] - 1s 11ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 19/20
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 20/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 1/20
# 75/75 [==============================] - 5s 11ms/step - loss: 0.2656 - accuracy: 0.5358 - val_loss: 0.2533 - val_accuracy: 0.5917
# Epoch 2/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2489 - accuracy: 0.6196 - val_loss: 0.2385 - val_accuracy: 0.7083
# Epoch 3/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2290 - accuracy: 0.7379 - val_loss: 0.2126 - val_accuracy: 0.8383
# Epoch 4/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1973 - accuracy: 0.8558 - val_loss: 0.1772 - val_accuracy: 0.9133
# Epoch 5/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1630 - accuracy: 0.9296 - val_loss: 0.1461 - val_accuracy: 0.9583
# Epoch 6/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1357 - accuracy: 0.9667 - val_loss: 0.1245 - val_accuracy: 0.9567
# Epoch 7/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1165 - accuracy: 0.9779 - val_loss: 0.1078 - val_accuracy: 0.9783
# Epoch 8/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1010 - accuracy: 0.9887 - val_loss: 0.0948 - val_accuracy: 1.0000
# Epoch 9/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0893 - accuracy: 0.9954 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 10/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9971 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 11/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0736 - accuracy: 0.9987 - val_loss: 0.0714 - val_accuracy: 1.0000
# Epoch 12/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0680 - accuracy: 0.9992 - val_loss: 0.0662 - val_accuracy: 1.0000
# Epoch 13/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 0.9992 - val_loss: 0.0620 - val_accuracy: 1.0000
# Epoch 14/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0592 - accuracy: 0.9996 - val_loss: 0.0581 - val_accuracy: 1.0000
# Epoch 15/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 16/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0526 - accuracy: 0.9996 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 17/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 18/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.0463 - val_accuracy: 1.0000
# Epoch 19/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0446 - accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 1.0000
# Epoch 20/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9983
# Epoch 1/20
# 75/75 [==============================] - 2s 8ms/step - loss: 0.6379 - accuracy: 0.5717 - val_loss: 0.5223 - val_accuracy: 0.7350
# Epoch 2/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.4799 - accuracy: 0.7708 - val_loss: 0.4005 - val_accuracy: 0.8900
# Epoch 3/20
# 75/75 [==============================] - 1s 7ms/step - loss: 0.3506 - accuracy: 0.8867 - val_loss: 0.2607 - val_accuracy: 0.9450
# Epoch 4/20
# 75/75 [==============================] - 1s 7ms/step - loss: 0.2431 - accuracy: 0.9333 - val_loss: 0.1633 - val_accuracy: 0.9683
# Epoch 5/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1853 - accuracy: 0.9463 - val_loss: 0.1184 - val_accuracy: 0.9867
# Epoch 6/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1589 - accuracy: 0.9533 - val_loss: 0.0954 - val_accuracy: 0.9867
# Epoch 7/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1445 - accuracy: 0.9558 - val_loss: 0.0805 - val_accuracy: 0.9850
# Epoch 8/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1391 - accuracy: 0.9588 - val_loss: 0.0726 - val_accuracy: 1.0000
# Epoch 9/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1338 - accuracy: 0.9592 - val_loss: 0.0659 - val_accuracy: 0.9867
# Epoch 10/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1324 - accuracy: 0.9596 - val_loss: 0.0680 - val_accuracy: 0.9767
# Epoch 11/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1340 - accuracy: 0.9571 - val_loss: 0.0571 - val_accuracy: 0.9900
# Epoch 12/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1309 - accuracy: 0.9592 - val_loss: 0.0530 - val_accuracy: 0.9917
# Epoch 13/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1292 - accuracy: 0.9592 - val_loss: 0.0518 - val_accuracy: 0.9917
# Epoch 14/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1298 - accuracy: 0.9588 - val_loss: 0.0590 - val_accuracy: 0.9983
# Epoch 15/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1296 - accuracy: 0.9592 - val_loss: 0.0537 - val_accuracy: 0.9983
# Epoch 16/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 0.9596 - val_loss: 0.0510 - val_accuracy: 0.9983
# Epoch 17/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1273 - accuracy: 0.9592 - val_loss: 0.0497 - val_accuracy: 0.9967
# Epoch 18/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1269 - accuracy: 0.9596 - val_loss: 0.0467 - val_accuracy: 1.0000
# Epoch 19/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1324 - accuracy: 0.9579 - val_loss: 0.0465 - val_accuracy: 0.9967
# Epoch 20/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9588 - val_loss: 0.0468 - val_accuracy: 0.9983
# Epoch 1/20
# 75/75 [==============================] - 4s 12ms/step - loss: 0.2784 - accuracy: 0.5008 - val_loss: 0.2585 - val_accuracy: 0.5583
# Epoch 2/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2545 - accuracy: 0.5971 - val_loss: 0.2410 - val_accuracy: 0.6917
# Epoch 3/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2322 - accuracy: 0.7267 - val_loss: 0.2088 - val_accuracy: 0.8450
# Epoch 4/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1927 - accuracy: 0.8758 - val_loss: 0.1647 - val_accuracy: 0.9350
# Epoch 5/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1555 - accuracy: 0.9246 - val_loss: 0.1319 - val_accuracy: 0.9500
# Epoch 6/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1317 - accuracy: 0.9388 - val_loss: 0.1117 - val_accuracy: 0.9883
# Epoch 7/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1172 - accuracy: 0.9483 - val_loss: 0.0992 - val_accuracy: 0.9650
# Epoch 8/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1072 - accuracy: 0.9500 - val_loss: 0.0893 - val_accuracy: 0.9733
# Epoch 9/20
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0998 - accuracy: 0.9546 - val_loss: 0.0802 - val_accuracy: 0.9950
# Epoch 10/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0935 - accuracy: 0.9567 - val_loss: 0.0742 - val_accuracy: 0.9933
# Epoch 11/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0891 - accuracy: 0.9571 - val_loss: 0.0704 - val_accuracy: 0.9867
# Epoch 12/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0858 - accuracy: 0.9575 - val_loss: 0.0661 - val_accuracy: 0.9867
# Epoch 13/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0826 - accuracy: 0.9571 - val_loss: 0.0625 - val_accuracy: 0.9917
# Epoch 14/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0801 - accuracy: 0.9583 - val_loss: 0.0595 - val_accuracy: 0.9883
# Epoch 15/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0778 - accuracy: 0.9571 - val_loss: 0.0552 - val_accuracy: 1.0000
# Epoch 16/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0756 - accuracy: 0.9600 - val_loss: 0.0531 - val_accuracy: 0.9983
# Epoch 17/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 0.9571 - val_loss: 0.0520 - val_accuracy: 0.9933
# Epoch 18/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9575 - val_loss: 0.0497 - val_accuracy: 0.9950
# Epoch 19/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 0.9600 - val_loss: 0.0477 - val_accuracy: 0.9983
# Epoch 20/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0697 - accuracy: 0.9588 - val_loss: 0.0470 - val_accuracy: 0.9917
# Epoch 1/20
# 75/75 [==============================] - 1s 6ms/step - loss: 0.6856 - accuracy: 0.5658 - val_loss: 0.5473 - val_accuracy: 0.7183
# Epoch 2/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.6082 - accuracy: 0.6879 - val_loss: 0.4735 - val_accuracy: 0.8817
# Epoch 3/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5723 - accuracy: 0.7433 - val_loss: 0.4050 - val_accuracy: 0.8933
# Epoch 4/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5497 - accuracy: 0.7625 - val_loss: 0.3690 - val_accuracy: 0.9550
# Epoch 5/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5362 - accuracy: 0.7746 - val_loss: 0.3257 - val_accuracy: 0.9567
# Epoch 6/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5310 - accuracy: 0.7804 - val_loss: 0.2982 - val_accuracy: 0.9567
# Epoch 7/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5293 - accuracy: 0.7850 - val_loss: 0.3206 - val_accuracy: 0.9783
# Epoch 8/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5274 - accuracy: 0.7862 - val_loss: 0.2922 - val_accuracy: 0.9767
# Epoch 9/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5256 - accuracy: 0.7892 - val_loss: 0.3018 - val_accuracy: 0.9967
# Epoch 10/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5232 - accuracy: 0.7900 - val_loss: 0.3082 - val_accuracy: 0.9917
# Epoch 11/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5201 - accuracy: 0.7933 - val_loss: 0.2954 - val_accuracy: 0.9883
# Epoch 12/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5243 - accuracy: 0.7925 - val_loss: 0.2926 - val_accuracy: 0.9950
# Epoch 13/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5212 - accuracy: 0.7946 - val_loss: 0.2883 - val_accuracy: 0.9967
# Epoch 14/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5200 - accuracy: 0.7925 - val_loss: 0.2741 - val_accuracy: 0.9733
# Epoch 15/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5187 - accuracy: 0.7900 - val_loss: 0.2757 - val_accuracy: 0.9900
# Epoch 16/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5189 - accuracy: 0.7904 - val_loss: 0.2937 - val_accuracy: 0.9967
# Epoch 17/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5197 - accuracy: 0.7954 - val_loss: 0.2807 - val_accuracy: 0.9933
# Epoch 18/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5174 - accuracy: 0.7967 - val_loss: 0.2861 - val_accuracy: 0.9950
# Epoch 19/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5189 - accuracy: 0.7917 - val_loss: 0.2729 - val_accuracy: 0.9950
# Epoch 20/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5171 - accuracy: 0.7954 - val_loss: 0.2817 - val_accuracy: 0.9950
# Epoch 1/20
# 75/75 [==============================] - 6s 19ms/step - loss: 0.2810 - accuracy: 0.5208 - val_loss: 0.2584 - val_accuracy: 0.5800
# Epoch 2/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.2744 - accuracy: 0.5746 - val_loss: 0.2474 - val_accuracy: 0.7117
# Epoch 3/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2652 - accuracy: 0.6542 - val_loss: 0.2250 - val_accuracy: 0.7967
# Epoch 4/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2515 - accuracy: 0.7029 - val_loss: 0.1980 - val_accuracy: 0.9033
# Epoch 5/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2371 - accuracy: 0.7496 - val_loss: 0.1716 - val_accuracy: 0.9450
# Epoch 6/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2258 - accuracy: 0.7800 - val_loss: 0.1521 - val_accuracy: 0.9650
# Epoch 7/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2177 - accuracy: 0.7879 - val_loss: 0.1366 - val_accuracy: 0.9667
# Epoch 8/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2123 - accuracy: 0.7900 - val_loss: 0.1252 - val_accuracy: 0.9867
# Epoch 9/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2079 - accuracy: 0.7950 - val_loss: 0.1167 - val_accuracy: 0.9967
# Epoch 10/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2049 - accuracy: 0.7967 - val_loss: 0.1091 - val_accuracy: 0.9900
# Epoch 11/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2026 - accuracy: 0.7975 - val_loss: 0.1033 - val_accuracy: 0.9933
# Epoch 12/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2009 - accuracy: 0.7975 - val_loss: 0.0982 - val_accuracy: 1.0000
# Epoch 13/20
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1993 - accuracy: 0.7983 - val_loss: 0.0952 - val_accuracy: 1.0000
# Epoch 14/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1982 - accuracy: 0.7992 - val_loss: 0.0895 - val_accuracy: 0.9900
# Epoch 15/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1973 - accuracy: 0.7987 - val_loss: 0.0865 - val_accuracy: 0.9917
# Epoch 16/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1968 - accuracy: 0.7992 - val_loss: 0.0825 - val_accuracy: 0.9983
# Epoch 17/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1960 - accuracy: 0.7996 - val_loss: 0.0815 - val_accuracy: 1.0000
# Epoch 18/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1952 - accuracy: 0.7992 - val_loss: 0.0782 - val_accuracy: 1.0000
# Epoch 19/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1947 - accuracy: 0.8000 - val_loss: 0.0763 - val_accuracy: 0.9950
# Epoch 20/20
# 75/75 [==============================] - 1s 8ms/step - loss: 0.1942 - accuracy: 0.7996 - val_loss: 0.0747 - val_accuracy: 1.0000

# %%
plot_synthetic_results(*datasets['noise free'], results['noise free'], 'Noise free dataset')
plot_synthetic_results(*datasets['margin'], results['margin'], '20% margin noise')
plot_synthetic_results(*datasets['global'], results['global'], '20% global noise')
# Out:
# 82/82 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 2ms/step

# %%
ssl._create_default_https_context = ssl._create_unverified_context
(X_train, y_train), (X_valid, y_valid) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
plot_cifar(X_train, y_train)

# %%
y_train_small_noise, small_noise_idx = mix_cifar(y_train, 0.1)
y_train_large_noise, large_noise_idx = mix_cifar(y_train, 0.2)

# %%
plot_cifar(X_train[small_noise_idx], y_train_small_noise[small_noise_idx])

# %%
X_train = resnet50.preprocess_input(X_train)
X_valid = resnet50.preprocess_input(X_valid)

y_train = to_categorical(y_train)
y_train_small_noise = to_categorical(y_train_small_noise)
y_train_large_noise = to_categorical(y_train_large_noise)
y_valid = to_categorical(y_valid)

# %%
def cifar_model():
    return Sequential([
        UpSampling2D((7, 7), input_shape=(32, 32, 3)),
        ResNet50(
            include_top=False,
            weights="imagenet",
            classes=10,
            pooling='avg'
        ),
        Flatten(),
        Dense(1024),
        Dense(512),
        Dense(10)
    ])

# %%
model = cifar_model()
model.save_weights('model.h5')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
datasets = {'noise free': (X_train, y_train),
            'small': (X_train, y_train_small_noise),
            'large': (X_train, y_train_large_noise)}
temp_vals = [(1.0, 1.0), (0.8, 1.2), (0.5, 2.0), (0.2, 4.0)]

# %%
best_lr = {}
finders = {}
for temps in temp_vals:
    model.load_weights('model.h5')
    model.compile(loss=BiTemperedWrapper(*temps), optimizer=SGD(momentum=0.8), metrics=['accuracy'])

    lr_finder = LRFinder(model)
    lr_finder.find(X_train, y_train, start_lr=1e-10, end_lr=100, batch_size=64)
    lr, loss = get_best_lr(lr_finder)
    best_lr[temps] = lr
    finders[temps] = lr_finder
# Out:
#  16/782 [..............................] - ETA: 10:36:38 - loss: 2.9074 - accuracy: 0.0693

# %%
plot_lr_finding_results(finders, get_best_lr)

# %%
results = {}
for dataset_name, (X_data, y_data) in datasets.items():
    results[dataset_name] = {}
    for temps in temp_vals:
        model.load_weights('model.h5')
        results[dataset_name][temps] = {}
        model.compile(loss=BiTemperedWrapper(*temps), optimizer=SGD(learning_rate=best_lr[temps], momentum=0.8), metrics=['accuracy'])
        history = model.fit(X_data, y_data, validation_data=(X_valid, y_valid), batch_size=64, epochs=40, steps_per_epoch=100)

        results[dataset_name][temps]['history'] = history.history
        np.save(f'{dataset_name}_{temps}', history.history)
        model.save_weights(f'{dataset_name}_{temps}.h5')

# %%
plot_cifar_results(results['noise free'], 'Noise free dataset', max_annotations=[[0.88,0.9],[0.6,0.9],[0.75,0.75],[0.75,0.5]])
plot_cifar_results(results['small'], '10% noise', max_annotations=[[0.52,0.9],[0.1,0.9]])
plot_cifar_results(results['large'], '20% noise', max_annotations=[[0.57,0.9],[0.12,0.9]])
